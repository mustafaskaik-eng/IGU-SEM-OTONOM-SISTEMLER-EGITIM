# %%
Der_no= 4 # integer (int) Veri Türü
pi_sayisi= 3.14159 # Flout (flout) Veri Türü
Dersin_ismi= "Python - Veri Yapilar ve Algoritmalar" # String (str) Veri Türü

durumu1=True
durumu2=False

print(Der_no)
print(Dersin_ismi)
print(pi_sayisi)
print(durumu1)
print(durumu2)
# Out:
# 4
# Python - Veri Yapilar ve Algoritmalar
# 3.14159
# True
# False

# %%
a=7
b=3
print("Çarpma:", a*b)
print("Üs alma:", a**b)
print("Mod:", a%b)
# Out:
# Çarpma: 21
# Üs alma: 343
# Mod: 1

# %%
a = 7
b = 3
print("a == b:",a==b)
print("a<b:", a<b)
# Out:
# a == b: False
# a<b: False

# %%
a=True
b=False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)
# Out:
# a and b: False
# a or b: True
# not a: False

# %%
x=7
x+=3 # x = x + 3
print(x)
# Out:
# 10

# %%
print(7&3) # 3
print(7|3) # 7
print(7^3) # 4
print(~3) # -4
print(7<<3) # 56
# Out:
# 3
# 7
# 4
# -4
# 56

# %% [markdown]
# If yapısı örnekler

# %%
a=10
if a>0:
  a=a+1
print(a)
# Out:
# 11

# %%
a=5
b=4
c=0
if a>0 and b>0:
  c=a*b+b
print(c)
# Out:
# 24

# %%
a=5
b=4
c=0
if a>0 and b>0:
  c=a+b
  c=a*a+c
print(c)
# Out:
# 34

# %%
a=4
b=1
if a>b:
  print(a)
else:
  print(b)
# Out:
# 4

# %%
a=4
b=1
c=9
sonuc=0
if a>0:
  sonuc+=1
  sonuc=a*c-b
  print(sonuc)
else:
    sonuc-=1
    sonuc= a/c+b
    print(sonuc)
# Out:
# 35

# %%
degisken=0
sonuc=0
if degisken==1:
  sonuc+=1
  print(sonuc)
elif degisken==2:
  sonuc+=2
  print(sonuc)
elif degisken==3:
  sonuc+=3
  print(sonuc)
else:
  sonuc=0
  print(sonuc)
# Out:
# 0

# %%
for i in range(1,11):
  print("Sayi-listesi:",i)
# Out:
# Sayi-listesi: 1
# Sayi-listesi: 2
# Sayi-listesi: 3
# Sayi-listesi: 4
# Sayi-listesi: 5
# Sayi-listesi: 6
# Sayi-listesi: 7
# Sayi-listesi: 8
# Sayi-listesi: 9
# Sayi-listesi: 10

# %%
for ch in range(ord('A'),ord('Z')+1):
  print('alfabe listesi:',chr(ch))
# Out:
# alfabe listesi: A
# alfabe listesi: B
# alfabe listesi: C
# alfabe listesi: D
# alfabe listesi: E
# alfabe listesi: F
# alfabe listesi: G
# alfabe listesi: H
# alfabe listesi: I
# alfabe listesi: J
# alfabe listesi: K
# alfabe listesi: L
# alfabe listesi: M
# alfabe listesi: N
# alfabe listesi: O
# alfabe listesi: P
# alfabe listesi: Q
# alfabe listesi: R
# alfabe listesi: S
# alfabe listesi: T
# alfabe listesi: U
# alfabe listesi: V
# alfabe listesi: W
# alfabe listesi: X
# alfabe listesi: Y
# alfabe listesi: Z

# %%
x=3
c=0
while c<3:
  print('ekran çıktısı:',c,x)
  x=x*x
  c=c+1
  print('döngü sonuŞ',c,x)
# Out:
# ekran çıktısı: 0 3
# döngü sonuŞ 1 9
# ekran çıktısı: 1 9
# döngü sonuŞ 2 81
# ekran çıktısı: 2 81
# döngü sonuŞ 3 6561

# %%
sayac=4
while sayac*sayac<=1000:
  print('döngü sonu:',sayac)
  sayac+=1
# Out:
# döngü sonu: 4
# döngü sonu: 5
# döngü sonu: 6
# döngü sonu: 7
# döngü sonu: 8
# döngü sonu: 9
# döngü sonu: 10
# döngü sonu: 11
# döngü sonu: 12
# döngü sonu: 13
# döngü sonu: 14
# döngü sonu: 15
# döngü sonu: 16
# döngü sonu: 17
# döngü sonu: 18
# döngü sonu: 19
# döngü sonu: 20
# döngü sonu: 21
# döngü sonu: 22
# döngü sonu: 23
# döngü sonu: 24
# döngü sonu: 25
# döngü sonu: 26
# döngü sonu: 27
# döngü sonu: 28
# döngü sonu: 29
# döngü sonu: 30
# döngü sonu: 31

# %%
sayi=int(input("Bir sayı girin:"))
if sayi %5==0:
  print("5'in kuvvetidir")
else:
  print("5'in kuvveti degildir")
# Out:
# Bir sayı girin:6
# 5'in kuvveti degildir

# %%
yil=int(input("bir yil girin:"))
if yil %4==0:
  print("Artık yıldır")
else:
  print("Artık yıl degildir")
# Out:
# bir yil girin:7
# Artık yıl degildir

# %%
sayi=1
s=0
toplam=0
while sayi !=0:
  sayi=int(input("Bir sayi girin(0 ile çıkabilirsiniz):"))
  if sayi !=0:
    toplam+=sayi
    s +=1
if s==0:
  print("sayi girisi yapmadiniz ")
else:
  ortalama= toplam/s
  print(toplam)
  print(ortalama)
# Out:
# Bir sayi girin(0 ile çıkabilirsiniz):0
# sayi girisi yapmadiniz

# %%
# List veri tipi örneği - 1) Bir listenin elemanlarının toplam, maksimum ve minimum değerlerini bulma
sayilar = [10, 20, 30, 40, 50]

# Toplam hesaplama
toplam = sum(sayilar)
print("Toplam:", toplam)

# Maksimum ve minimum değer bulma
print("En büyük sayı:", max(sayilar))
print("En küçük sayı:", min(sayilar))
# Out:
# Toplam: 150
# En büyük sayı: 50
# En küçük sayı: 10

# %%
# List veri tipi örneği - 2) For ve if ile çift sayıları bulma
liste = [2, 3, 5, 6, 8, 11, 14]

numaralistesi = [] # Çift sayıları tutmak için boş liste

for i in liste:
    if i % 2 == 0:
        numaralistesi.append(i)

print("Listede bulunan çift sayılar:", numaralistesi)
print("Adet çift sayı", len(numaralistesi), "bulunmaktadır !!!")
# Out:
# Listede bulunan çift sayılar: [2, 6, 8, 14]
# Adet çift sayı 4 bulunmaktadır !!!

# %%
# List veri tipi örneği - 3) Malzeme Listesi

liste = ["elma", "muz", "çilek", "su", "cikolata"] # Malzeme Listesi

aranacak_urun = "muz" # Aranacak eleman

if aranacak_urun in liste:
    print(aranacak_urun, "liste içerisinde mevcut.")
else:
    print(aranacak_urun, "liste içerisinde mevcut değil.")
# Out:
# muz liste içerisinde mevcut.

# %%
# List veri tipi örneği - 4) Malzeme Listesi

liste = ["elma", "muz", "çilek", "su", "cikolata"]

aranacak_urun = input("Aranacak Ürün Nedir? ") # Aranacak eleman

if aranacak_urun in liste:
    print(aranacak_urun, "liste içerisinde mevcut.")
else:
    print(aranacak_urun, "liste içerisinde mevcut değil.")
# Out:
# Aranacak Ürün Nedir? muz
# muz liste içerisinde mevcut.

# %%
renkler = ("Kırmızı", "Mavi", "Yeşil") # Demet (Tuple) veri yapısı
print(renkler[1]) # 'Mavi' çıktısı verir
# Out:
# Mavi

# %%
# Demet veri tipi örneği - 1) Haftanın günlerini bir demet içinde tanımlama
hafta_gunleri = ("Pazartesi", "Salı", "Çarşamba", "Perşembe", "Cuma", "Cumartesi", "Pazar")

# Elemanları yazdırma
print("Haftanın günleri:")
for gun in hafta_gunleri:
    print(gun)
# Out:
# Haftanın günleri:
# Pazartesi
# Salı
# Çarşamba
# Perşembe
# Cuma
# Cumartesi
# Pazar

# %%
# Demet veri tipi örneği - 2) Öğrencilerin adları ve notları bir demette saklanıyor
ogrenciler = (
    ("Ali", (85, 90, 78)),
    ("Ayşe", (88, 76, 92)),
    ("Mehmet", (70, 85, 80)),
    ("Zeynep", (95, 90, 93))
)

# Her öğrencinin ortalama notunu hesaplama
for ogrenci in ogrenciler:
    isim = ogrenci[0]
    notlar = ogrenci[1]
    ortalama = sum(notlar) / len(notlar)
    print(isim, " adlı öğrencinin ortalaması: ", ortalama)
# Out:
# Ali  adlı öğrencinin ortalaması:  84.33333333333333
# Ayşe  adlı öğrencinin ortalaması:  85.33333333333333
# Mehmet  adlı öğrencinin ortalaması:  78.33333333333333
# Zeynep  adlı öğrencinin ortalaması:  92.66666666666667

# %%
ogrenci = {"ad": "Ali", "yas": 30} # Sözlük (Dictionary) veri yapısı
ogrenci["okul"] = "İGÜ"     # Yeni anahtar ekleme
print(ogrenci["ad"])   # 'Ali' çıktısı verir
print(ogrenci)
# Out:
# Ali
# {'ad': 'Ali', 'yas': 30, 'okul': 'İGÜ'}

# %%
# Sözlük veri tipi örneği - 1 Öğrenci Bilgileri

ogrenci = {
    "isim:": "Ali",
    "yaş:": 25,
    "ders:": "Python Programlama",
    "not:": 90
}

# Bilgilerin yazdırılması
print("Öğrenci Bilgileri:")
for anahtar, değer in ogrenci.items():
    print(anahtar, değer)
# Out:
# Öğrenci Bilgileri:
# isim: Ali
# yaş: 25
# ders: Python Programlama
# not: 90

# %%
# Sözlük veri tipi örneği - 2 Ürünler ve fiyatları
sepet = {"Elma": 3, "Muz": 2, "Portakal": 4}

# Toplam tutar hesaplama
toplam_tutar = sum(sepet.values())
print("Toplam Tutar:", toplam_tutar, "TL")

# Yeni ürün ekleme
sepet["Kiraz"] = 6
print("Güncellenmiş Sepet:", sepet)
# Out:
# Toplam Tutar: 9 TL
# Güncellenmiş Sepet: {'Elma': 3, 'Muz': 2, 'Portakal': 4, 'Kiraz': 6}
